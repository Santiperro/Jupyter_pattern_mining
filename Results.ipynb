# %%
import pandas as pd

translated_bachelors_rules = pd.read_excel(r'C:\Users\megan\PycharmProjects\PatternMining\translated_bachelors_transactions.xlsx')
translated_majors_rules = pd.read_excel(r'C:\Users\megan\PycharmProjects\PatternMining\translated_majors_transactions.xlsx')

translated_bachelors_rules.rename(columns={'Unnamed: 0' : 'Index'}, inplace=True)
translated_majors_rules.rename(columns={'Unnamed: 0' : 'Index'}, inplace=True)

translated_bachelors_rules = bachelors_df.set_index('Index')
translated_majors_rules = majors_df.set_index('Index')
# Out:
#     Unnamed: 0                                    antecedents  \
# 0            0                                   ['Закончил']
# 1            1                              ['Высокобальник']
# 2            2                                       ['ВКР5']
# 3            3                              ['Высокобальник']
# 4            4                   ['Нет пересдачи за семестр']
# 5            5                              ['Высокобальник']
# 6            6                           ['Не высокобальник']
# 7            7                  ['Есть пересдача за семестр']
# 8            8                                       ['ВКР5']
# 9            9                                   ['Закончил']
# 10          10                   ['Нет пересдачи за семестр']
# 11          11                                   ['Закончил']
# 12          12                   ['Нет пересдачи за семестр']
# 13          13                                       ['ВКР5']
# ...

# %%
translated_majors_rules
# Out:
#     Unnamed: 0                                        antecedents  \
# 0            0                               ['Не высокобальник']
# 1            1                                       ['Закончил']
# 2            2                                       ['Закончил']
# 3            3                  ['Качественная успеваемость 100']
# 4            4                                           ['ВКР5']
# 5            5                                       ['Закончил']
# 6            6                       ['Нет пересдачи за семестр']
# 7            7                                       ['Закончил']
# 8            8                       ['Нет пересдачи за семестр']
# 9            9                  ['Качественная успеваемость 100']
# 10          10                       ['Нет пересдачи за семестр']
# 11          11                                           ['ВКР5']
# 12          12   ['Нет пересдачи за семестр', 'Не высокобальник']
# ...
